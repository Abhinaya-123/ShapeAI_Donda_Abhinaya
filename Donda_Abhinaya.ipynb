# %%
from keras.datasets import mnist
data=mnist.load_data()

# %%
(x_train,y_train),(x_test,y_test)=data

# %%
x_train[0].shape
# Out:
# (28, 28)

# %%
x_train = x_train.reshape((x_train.shape[0], 28*28)).astype('float32')
x_test = x_test.reshape((x_test.shape[0], 28*28)).astype('float32')

# %%
x_train = x_train /255
x_test = x_test /255

# %%
from keras.utils import np_utils
 
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)
num_classes = y_test.shape[1]

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(32,input_dim = 28*28,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dense(10,activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_30 (Dense)             (None, 32)                25120
# _________________________________________________________________
# dense_31 (Dense)             (None, 64)                2112
# _________________________________________________________________
# dense_32 (Dense)             (None, 10)                650
# =================================================================
# Total params: 27,882
# Trainable params: 27,882
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,y_train, epochs=10, batch_size=100)
# Out:
# Epoch 1/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0283 - accuracy: 0.9909
# Epoch 2/10
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0264 - accuracy: 0.9915
# Epoch 3/10
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0240 - accuracy: 0.9924
# Epoch 4/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0218 - accuracy: 0.9929
# Epoch 5/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0207 - accuracy: 0.9938
# Epoch 6/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0200 - accuracy: 0.9937
# Epoch 7/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0185 - accuracy: 0.9945
# Epoch 8/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0181 - accuracy: 0.9942
# Epoch 9/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0160 - accuracy: 0.9950
# Epoch 10/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0162 - accuracy: 0.9947

# %%
scores = model.evaluate(x_test, y_test)
print(scores)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1382 - accuracy: 0.9666
# [0.13823865354061127, 0.9666000008583069]
